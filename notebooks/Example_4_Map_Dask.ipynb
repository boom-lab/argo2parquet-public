# %% [markdown]
# ### Example 4 - Map of chlorophyll content in the North West Atlantic - Dask approach
#
# This example will show you how to read and manipulate Argo profiles data stored in parquet format in your machine, exploiting [dask](https://docs.dask.org/en/stable/) capabilities of dealing with larger-than-memory data.
#
# The data are stored across multiple files: we will load into memory only what we need by applying some filters, and we will create a map showing the chlorophyll content in the North West Atlantic.
#
# ##### Note on performance
#
# I have developed this example on WHOI's HPC cluster. If you have access to an HPC machine, I recommend using it. If not, filter more aggressively or skip the parts where a lot of data is loaded (the first example loads ~45 GB).
#
# As I am accessing data in a cluster, reading times are of course influenced by my internet connection, besides the file format.
#
# ##### Note on parquet files
#
# The original netCDF Argo files have been converted to parquet format, which provides faster read operations.
#
# There are a couple of ways to read parquet files in Python. In this example we will use Dask. Dask uses lazy evaluation to optimize operations, i.e. it first builds a graph of the computation it needs to carry out, and then eventually optimizes them and computes only the necessary ones. This means that when we call some function on a dataframe (e.g. `mean()`), a delayed object is created. To execute the computation, we need to call the `compute()` of the delayed object we created.
#
# To access data with pyarrow and pandas see Example 1 notebook. Note that Dask, too, uses pyarrow behind the scenes, and that dask dataframes are almost identical to pandas'.
#
# Generally speaking, you'll want to use Dask only if you need to operate on a large amount of data so that you can benefit from its parallelization capabilities. You should avoid Dask whenever the data fits in your RAM.
#
# #### Getting started
#
# We start by importing the necessary modules and setting the path and filenames of the parquet files.  For a list of modules that you need to install, you can look at the [README.md file in the repository](https://github.com/boom-lab/nc2parquet).
#
# We also provide the schema (e.g. column names and data types) that pyarrow will need to read the parquet database. This speeds up read operations, as pyarrow does not need to guess the schema from the files.

# %%
from datetime import datetime
import xarray as xr
import pyarrow as pa
import pyarrow.parquet as pq
from pprint import pprint
import numpy as np

import dask
import dask.dataframe as dd

# Paths on Poseidon cluster
parquet_dir = '/vortexfs1/home/enrico.milanese/projects/ARGO/nc2parquet/data_test/parquet/bgc'

# Setting up parquet schema
schema_path = '../schemas/ArgoBGC_schema.metadata'
BGC_schema = pq.read_schema(schema_path)

# %% [markdown]
# We now want to set up our filter to read only the data from the NWA (i.e. latitude between 34$^\circ$ and 60$^\circ$, longitude between -45$^\circ$ and -78$^\circ$).

# %%
filter_coords = [("LATITUDE",">",34), ("LATITUDE","<",80),
                 ("LONGITUDE",">",-78), ("LONGITUDE","<",-50)]

# %%
# %%time
ddf = dd.read_parquet(
    parquet_dir,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True} ,
    schema=BGC_schema,
    filters = filter_coords
    )
# Out:
# CPU times: user 100 ms, sys: 49.2 ms, total: 150 ms
# Wall time: 177 ms

# %% [markdown]
# You probably noticed how fast this `read_parquet()` has been. This is because `ddf` is actually a delayed object, i.e. it stored the graph of operations it needs to execute, but it did not execute them. If we call `ddf`, we get the basic information (columns and data types), but the dataframe looks otherwise empty.

# %%
ddf
# Out:
# Dask DataFrame Structure:
#                PRES_ADJUSTED_QC TEMP_ADJUSTED_QC     DOXY PLATFORM_NUMBER PSAL_dPRES DOXY_ADJUSTED_ERROR     TEMP LATITUDE TEMP_dPRES PSAL_ADJUSTED_ERROR DOXY_ADJUSTED CYCLE_NUMBER PRES_QC PRES_ADJUSTED_ERROR TEMP_ADJUSTED_ERROR PSAL_ADJUSTED PSAL_ADJUSTED_QC DOXY_ADJUSTED_QC  DOXY_QC PSAL_QC            JULD TEMP_QC LONGITUDE     PSAL TEMP_ADJUSTED     PRES PRES_ADJUSTED DOXY_dPRES N_PROF N_LEVELS  CHLA_QC CHLA_ADJUSTED_QC BBP700_ADJUSTED NITRATE_ADJUSTED NITRATE_dPRES CHLA_dPRES PH_IN_SITU_TOTAL_ADJUSTED_QC NITRATE_QC NITRATE_ADJUSTED_ERROR PH_IN_SITU_TOTAL_dPRES NITRATE_ADJUSTED_QC  NITRATE BBP700_ADJUSTED_ERROR PH_IN_SITU_TOTAL_QC PH_IN_SITU_TOTAL PH_IN_SITU_TOTAL_ADJUSTED     CHLA BBP700_QC CHLA_ADJUSTED CHLA_ADJUSTED_ERROR PH_IN_SITU_TOTAL_ADJUSTED_ERROR   BBP700 BBP700_ADJUSTED_QC BBP700_dPRES CDOM_dPRES DOWN_IRRADIANCE380_ADJUSTED_ERROR DOWNWELLING_PAR_QC CDOM_ADJUSTED_QC DOWN_IRRADIANCE412_ADJUSTED_ERROR     CDOM DOWNWELLING_PAR_ADJUSTED_ERROR DOWNWELLING_PAR DOWN_IRRADIANCE412_ADJUSTED_QC DOWN_IRRADIANCE412_ADJUSTED DOWN_IRRADIANCE380_dPRES DOWNWELLING_PAR_dPRES  CDOM_QC DOWN_IRRADIANCE490_QC DOWN_IRRADIANCE490_dPRES DOWN_IRRADIANCE490 DOWN_IRRADIANCE490_ADJUSTED_ERROR CDOM_ADJUSTED DOWN_IRRADIANCE380_ADJUSTED_QC CDOM_ADJUSTED_ERROR DOWN_IRRADIANCE490_ADJUSTED DOWNWELLING_PAR_ADJUSTED_QC DOWN_IRRADIANCE490_ADJUSTED_QC DOWN_IRRADIANCE380_ADJUSTED DOWN_IRRADIANCE380 DOWN_IRRADIANCE412 DOWNWELLING_PAR_ADJUSTED DOWN_IRRADIANCE412_QC DOWN_IRRADIANCE412_dPRES DOWN_IRRADIANCE380_QC BBP532_ADJUSTED BBP532_QC   BBP532 BBP532_dPRES BBP532_ADJUSTED_QC BBP532_ADJUSTED_ERROR DOWN_IRRADIANCE443 DOWN_IRRADIANCE443_ADJUSTED_QC DOWN_IRRADIANCE443_ADJUSTED_ERROR DOWN_IRRADIANCE443_dPRES DOWN_IRRADIANCE443_ADJUSTED DOWN_IRRADIANCE443_QC DOWN_IRRADIANCE555_QC DOWN_IRRADIANCE555 DOWN_IRRADIANCE555_ADJUSTED DOWN_IRRADIANCE555_dPRES DOWN_IRRADIANCE555_ADJUSTED_QC   BBP470 CP660_ADJUSTED_QC CP660_QC BBP470_QC BBP470_dPRES BBP470_ADJUSTED_QC    CP660 BBP470_ADJUSTED CP660_ADJUSTED BBP470_ADJUSTED_ERROR CP660_ADJUSTED_ERROR DOWN_IRRADIANCE555_ADJUSTED_ERROR CP660_dPRES BISULFIDE_ADJUSTED BISULFIDE_dPRES BISULFIDE_ADJUSTED_QC BISULFIDE_ADJUSTED_ERROR BISULFIDE_QC BISULFIDE TURBIDITY_dPRES TURBIDITY_ADJUSTED TURBIDITY TURBIDITY_ADJUSTED_QC TURBIDITY_ADJUSTED_ERROR TURBIDITY_QC
# npartitions=48
#                           Int64            Int64  float32           Int64    float32             float32  float32  float64    float32             float32       float32        Int64   Int64             float32             float32       float32            Int64          float64  float64   Int64  datetime64[ns]   Int64   float64  float32       float32  float32       float32    float32  Int64    Int64  float64          float64         float32          float32       float32    float32                      float64    float64                float32                float32             float64  float32               float32             float64          float32                   float32  float32   float64       float32             float32                         float32  float32            float64      float32    float32                           float32            float64          float64                           float32  float32                        float32         float32                        float64                     float32                  float32               float32  float64               float64                  float32            float32                           float32       float32                        float64             float32                     float32                     float64                        float64                     float32            float32            float32                  float32               float64                  float32               float64         float32   float64  float32      float32            float64               float32            float32                        float64                           float32                  float32                     float32               float64               float64            float32                     float32                  float32                        float64  float32           float64  float64   float64      float32            float64  float32         float32        float32               float32              float32                           float32     float32            float32         float32               float64                  float32      float64   float32         float32            float32   float32               float64                  float32      float64
#                             ...              ...      ...             ...        ...                 ...      ...      ...        ...                 ...           ...          ...     ...                 ...                 ...           ...              ...              ...      ...     ...             ...     ...       ...      ...           ...      ...           ...        ...    ...      ...      ...              ...             ...              ...           ...        ...                          ...        ...                    ...                    ...                 ...      ...                   ...                 ...              ...                       ...      ...       ...           ...                 ...                             ...      ...                ...          ...        ...                               ...                ...              ...                               ...      ...                            ...             ...                            ...                         ...                      ...                   ...      ...                   ...                      ...                ...                               ...           ...                            ...                 ...                         ...                         ...                            ...                         ...                ...                ...                      ...                   ...                      ...                   ...             ...       ...      ...          ...                ...                   ...                ...                            ...                               ...                      ...                         ...                   ...                   ...                ...                         ...                      ...                            ...      ...               ...      ...       ...          ...                ...      ...             ...            ...                   ...                  ...                               ...         ...                ...             ...                   ...                      ...          ...       ...             ...                ...       ...                   ...                      ...          ...
# ...                         ...              ...      ...             ...        ...                 ...      ...      ...        ...                 ...           ...          ...     ...                 ...                 ...           ...              ...              ...      ...     ...             ...     ...       ...      ...           ...      ...           ...        ...    ...      ...      ...              ...             ...              ...           ...        ...                          ...        ...                    ...                    ...                 ...      ...                   ...                 ...              ...                       ...      ...       ...           ...                 ...                             ...      ...                ...          ...        ...                               ...                ...              ...                               ...      ...                            ...             ...                            ...                         ...                      ...                   ...      ...                   ...                      ...                ...                               ...           ...                            ...                 ...                         ...                         ...                            ...                         ...                ...                ...                      ...                   ...                      ...                   ...             ...       ...      ...          ...                ...                   ...                ...                            ...                               ...                      ...                         ...                   ...                   ...                ...                         ...                      ...                            ...      ...               ...      ...       ...          ...                ...      ...             ...            ...                   ...                  ...                               ...         ...                ...             ...                   ...                      ...          ...       ...             ...                ...       ...                   ...                      ...          ...
#                             ...              ...      ...             ...        ...                 ...      ...      ...        ...                 ...           ...          ...     ...                 ...                 ...           ...              ...              ...      ...     ...             ...     ...       ...      ...           ...      ...           ...        ...    ...      ...      ...              ...             ...              ...           ...        ...                          ...        ...                    ...                    ...                 ...      ...                   ...                 ...              ...                       ...      ...       ...           ...                 ...                             ...      ...                ...          ...        ...                               ...                ...              ...                               ...      ...                            ...             ...                            ...                         ...                      ...                   ...      ...                   ...                      ...                ...                               ...           ...                            ...                 ...                         ...                         ...                            ...                         ...                ...                ...                      ...                   ...                      ...                   ...             ...       ...      ...          ...                ...                   ...                ...                            ...                               ...                      ...                         ...                   ...                   ...                ...                         ...                      ...                            ...      ...               ...      ...       ...          ...                ...      ...             ...            ...                   ...                  ...                               ...         ...                ...             ...                   ...                      ...          ...       ...             ...                ...       ...                   ...                      ...          ...
#                             ...              ...      ...             ...        ...                 ...      ...      ...        ...                 ...           ...          ...     ...                 ...                 ...           ...              ...              ...      ...     ...             ...     ...       ...      ...           ...      ...           ...        ...    ...      ...      ...              ...             ...              ...           ...        ...                          ...        ...                    ...                    ...                 ...      ...                   ...                 ...              ...                       ...      ...       ...           ...                 ...                             ...      ...                ...          ...        ...                               ...                ...              ...                               ...      ...                            ...             ...                            ...                         ...                      ...                   ...      ...                   ...                      ...                ...                               ...           ...                            ...                 ...                         ...                         ...                            ...                         ...                ...                ...                      ...                   ...                      ...                   ...             ...       ...      ...          ...                ...                   ...                ...                            ...                               ...                      ...                         ...                   ...                   ...                ...                         ...                      ...                            ...      ...               ...      ...       ...          ...                ...      ...             ...            ...                   ...                  ...                               ...         ...                ...             ...                   ...                      ...          ...       ...             ...                ...       ...                   ...                      ...          ...
# Dask Name: read_parquet, 1 expression
# Expr=ReadParquetFSSpec(9129584)

# %% [markdown]
# We can check get a sneak peek of the data with the method `head()`, which loads the first 5 rows of the dataframe:

# %%
# %%time
ddf.head()
# Out:
# CPU times: user 267 ms, sys: 154 ms, total: 421 ms
# Wall time: 1.57 s
#    PRES_ADJUSTED_QC  TEMP_ADJUSTED_QC        DOXY  PLATFORM_NUMBER  \
# 0                 1                 1         NaN          1901378
# 1                 1                 1         NaN          1901378
# 2                 1                 8  188.885849          1901378
# 3                 1                 1         NaN          1901378
# 4                 1                 1         NaN          1901378
#
#    PSAL_dPRES  DOXY_ADJUSTED_ERROR       TEMP  LATITUDE  TEMP_dPRES  \
# 0         0.0                  NaN  26.016001    34.025         0.0
# 1         0.0                  NaN  26.017000    34.025         0.0
# 2         0.2             4.907148  26.017000    34.025         0.2
# 3         0.0                  NaN  26.017000    34.025         0.0
# 4         0.0                  NaN  26.017000    34.025         0.0
#
#    PSAL_ADJUSTED_ERROR  ...  BISULFIDE_ADJUSTED_QC  BISULFIDE_ADJUSTED_ERROR  \
# 0                 0.01  ...                    NaN                       NaN
# 1                 0.01  ...                    NaN                       NaN
# 2                 0.01  ...                    NaN                       NaN
# 3                 0.01  ...                    NaN                       NaN
# 4                 0.01  ...                    NaN                       NaN
#
#    BISULFIDE_QC  BISULFIDE  TURBIDITY_dPRES  TURBIDITY_ADJUSTED  TURBIDITY  \
# 0           NaN        NaN              NaN                 NaN        NaN
# 1           NaN        NaN              NaN                 NaN        NaN
# 2           NaN        NaN              NaN                 NaN        NaN
# 3           NaN        NaN              NaN                 NaN        NaN
# 4           NaN        NaN              NaN                 NaN        NaN
#
#    TURBIDITY_ADJUSTED_QC  TURBIDITY_ADJUSTED_ERROR  TURBIDITY_QC
# 0                    NaN                       NaN           NaN
# 1                    NaN                       NaN           NaN
# 2                    NaN                       NaN           NaN
# 3                    NaN                       NaN           NaN
# 4                    NaN                       NaN           NaN
#
# [5 rows x 126 columns]

# %% [markdown]
# This was still really fast, less than half a second! Let's now load all the dataframe into memory with the `compute()` method.

# %%
# %%time
ddf = ddf.compute()
ddf
# Out:
# CPU times: user 8.2 s, sys: 24.9 s, total: 33.1 s
# Wall time: 2.87 s
#        PRES_ADJUSTED_QC  TEMP_ADJUSTED_QC        DOXY  PLATFORM_NUMBER  \
# 0                     1                 1         NaN          1901378
# 1                     1                 1         NaN          1901378
# 2                     1                 8  188.885849          1901378
# 3                     1                 1         NaN          1901378
# 4                     1                 1         NaN          1901378
# ...                 ...               ...         ...              ...
# 33093                 0                 0         NaN          3901669
# 33094                 0                 0         NaN          3901669
# 33095                 0                 0         NaN          3901669
# 33096                 0                 0         NaN          3901669
# 33097                 0                 0         NaN          3901669
#
#        PSAL_dPRES  DOXY_ADJUSTED_ERROR       TEMP  LATITUDE  TEMP_dPRES  \
# 0             0.0                  NaN  26.016001  34.02500         0.0
# 1             0.0                  NaN  26.017000  34.02500         0.0
# 2             0.2             4.907148  26.017000  34.02500         0.2
# 3             0.0                  NaN  26.017000  34.02500         0.0
# 4             0.0                  NaN  26.017000  34.02500         0.0
# ...           ...                  ...        ...       ...         ...
# 33093         NaN                  NaN        NaN  52.46687         NaN
# 33094         NaN                  NaN        NaN  52.46687         NaN
# 33095         NaN                  NaN        NaN  52.46687         NaN
# 33096         NaN                  NaN        NaN  52.46687         NaN
# 33097         NaN                  NaN        NaN  52.46687         NaN
#
#        PSAL_ADJUSTED_ERROR  ...  BISULFIDE_ADJUSTED_QC  \
# 0                     0.01  ...                    NaN
# 1                     0.01  ...                    NaN
# 2                     0.01  ...                    NaN
# 3                     0.01  ...                    NaN
# 4                     0.01  ...                    NaN
# ...                    ...  ...                    ...
# 33093                  NaN  ...                    NaN
# 33094                  NaN  ...                    NaN
# 33095                  NaN  ...                    NaN
# 33096                  NaN  ...                    NaN
# 33097                  NaN  ...                    NaN
#
#        BISULFIDE_ADJUSTED_ERROR  BISULFIDE_QC  BISULFIDE  TURBIDITY_dPRES  \
# 0                           NaN           NaN        NaN              NaN
# 1                           NaN           NaN        NaN              NaN
# 2                           NaN           NaN        NaN              NaN
# 3                           NaN           NaN        NaN              NaN
# 4                           NaN           NaN        NaN              NaN
# ...                         ...           ...        ...              ...
# 33093                       NaN           NaN        NaN              NaN
# 33094                       NaN           NaN        NaN              NaN
# 33095                       NaN           NaN        NaN              NaN
# 33096                       NaN           NaN        NaN              NaN
# 33097                       NaN           NaN        NaN              NaN
#
#        TURBIDITY_ADJUSTED  TURBIDITY  TURBIDITY_ADJUSTED_QC  \
# 0                     NaN        NaN                    NaN
# 1                     NaN        NaN                    NaN
# 2                     NaN        NaN                    NaN
# 3                     NaN        NaN                    NaN
# 4                     NaN        NaN                    NaN
# ...                   ...        ...                    ...
# 33093                 NaN        NaN                    NaN
# 33094                 NaN        NaN                    NaN
# 33095                 NaN        NaN                    NaN
# 33096                 NaN        NaN                    NaN
# 33097                 NaN        NaN                    NaN
#
#        TURBIDITY_ADJUSTED_ERROR  TURBIDITY_QC
# 0                           NaN           NaN
# 1                           NaN           NaN
# 2                           NaN           NaN
# 3                           NaN           NaN
# 4                           NaN           NaN
# ...                         ...           ...
# 33093                       NaN           NaN
# 33094                       NaN           NaN
# 33095                       NaN           NaN
# 33096                       NaN           NaN
# 33097                       NaN           NaN
#
# [1071187 rows x 126 columns]

# %% [markdown]
# It took a few seconds to load the whole dataframe, much faster than using pyarrow as we did in Example 1!

# %%
# %%time
from datetime import datetime, timedelta
t0 = datetime(2023, 7, 1)
t1 = datetime(2023, 10, 31)

ref_var = 'CHLA_ADJUSTED'
cols = [ref_var,"LATITUDE","LONGITUDE","PRES_ADJUSTED","JULD"]
filter_coords_time_pres = [("LATITUDE",">",34), ("LATITUDE","<",80),
                           ("LONGITUDE",">",-78), ("LONGITUDE","<",-50),
                           ("JULD",">=",t0),("JULD","<=",t1),
                           ("PRES_ADJUSTED",">=",0),("PRES_ADJUSTED","<=",50),
                           (ref_var,">=",-1e30),(ref_var,"<=",+1e30),
                           (ref_var+"_QC",">=",1.0),(ref_var+"_QC","<=",2.0)]

ddf = dd.read_parquet(
    parquet_dir,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True} ,
    schema=BGC_schema,
    filters=filter_coords_time_pres,
    columns= cols
    )
# Out:
# CPU times: user 118 ms, sys: 3.61 ms, total: 122 ms
# Wall time: 123 ms

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from matplotlib import colormaps

# Convert 'JULD' column to datetime type
# df['JULD'] = pd.to_datetime(df['JULD'])

# Group by 'LATITUDE' and 'LONGITUDE', and aggregate by averaging over 'PRES_ADJUSTED', 'JULD', and 'CHLA_ADJUSTED'
grouped = ddf.groupby(['LATITUDE', 'LONGITUDE']).agg({
    'PRES_ADJUSTED': 'mean',  # Take the mean depth
    'JULD': lambda x: x.tolist(),  # Collect all time values into a list
    ref_var: 'mean'  # Take the mean intensity
}).reset_index().compute()

# Plotting using Cartopy
plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()

# Scatter plot
cbar_min = ddf[ref_var].quantile(q=0.1).compute()
cbar_max = ddf[ref_var].quantile(q=0.9).compute()
plt.scatter(grouped['LONGITUDE'], grouped['LATITUDE'], c=grouped[ref_var], vmin=cbar_min, vmax=cbar_max, cmap='cividis', transform=ccrs.PlateCarree())
plt.colorbar(label='Average ' + ref_var)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('North-West Atlantic average ' + ref_var)
plt.grid(True)
plt.xlim([-78, -45])
plt.ylim([30, 50])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 9
#       3 from matplotlib import colormaps
#       5 # Convert 'JULD' column to datetime type
#       6 # df['JULD'] = pd.to_datetime(df['JULD'])
#       7
#       8 # Group by 'LATITUDE' and 'LONGITUDE', and aggregate by averaging over 'PRES_ADJUSTED', 'JULD', and 'CHLA_ADJUSTED'
# ----> 9 grouped = ddf.groupby(['LATITUDE', 'LONGITUDE']).agg({
#      10     'PRES_ADJUSTED': 'mean',  # Take the mean depth
#      11     'JULD': lambda x: x.tolist(),  # Collect all time values into a list
#      12     ref_var: 'mean'  # Take the mean intensity
#      13 }).reset_index().compute()
#      15 # Plotting using Cartopy
#      16 plt.figure(figsize=(10, 6))
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_groupby.py:1946, in GroupBy.agg(self, *args, **kwargs)
#    1945 def agg(self, *args, **kwargs):
# -> 1946     return self.aggregate(*args, **kwargs)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_groupby.py:1925, in GroupBy.aggregate(self, arg, split_every, split_out, shuffle_method, **kwargs)
#    1922 if arg == "size":
#    1923     return self.size()
# -> 1925 result = new_collection(
#    1926     GroupbyAggregation(
#    1927         self.obj.expr,
#    1928         arg,
#    1929         self.observed,
#    1930         self.dropna,
#    1931         split_every,
#    1932         split_out,
#    1933         self.sort,
#    1934         shuffle_method,
#    1935         self._slice,
#    1936         *self.by,
#    1937     )
#    1938 )
#    1939 if relabeling and result is not None:
#    1940     if order is not None:
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_collection.py:4779, in new_collection(expr)
#    4777 def new_collection(expr):
#    4778     """Create new collection from an expr"""
# -> 4779     meta = expr._meta
#    4780     expr._name  # Ensure backend is imported
#    4781     return get_collection_type(meta)(expr)
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_groupby.py:436, in GroupbyAggregation._meta(self)
#     434 @functools.cached_property
#     435 def _meta(self):
# --> 436     return self._lower()._meta
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_reductions.py:439, in ApplyConcatApply._meta(self)
#     437 @functools.cached_property
#     438 def _meta(self):
# --> 439     meta = self._meta_chunk
#     440     aggregate = self.aggregate or (lambda x: x)
#     441     if self.combine:
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_groupby.py:210, in GroupByApplyConcatApply._meta_chunk(self)
#     207 @functools.cached_property
#     208 def _meta_chunk(self):
#     209     meta = meta_nonempty(self.frame._meta)
# --> 210     return self.chunk(meta, *self._by_meta, **self.chunk_kwargs)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_groupby.py:527, in DecomposableGroupbyAggregation.chunk_kwargs(self)
#     524 @property
#     525 def chunk_kwargs(self) -> dict:
#     526     return {
# --> 527         "funcs": self.agg_args["chunk_funcs"],
#     528         "sort": self.sort,
#     529         **_as_dict("observed", self.observed),
#     530         **_as_dict("dropna", self.dropna),
#     531     }
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_groupby.py:408, in GroupbyAggregationBase.agg_args(self)
#     405 @functools.cached_property
#     406 def agg_args(self):
#     407     keys = ["chunk_funcs", "aggregate_funcs", "finalizers"]
# --> 408     return dict(zip(keys, _build_agg_args(self.spec)))
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/dataframe/groupby.py:891, in _build_agg_args(spec)
#     888 if not isinstance(func, Aggregation):
#     889     func = funcname(known_np_funcs.get(func, func))
# --> 891 impls = _build_agg_args_single(
#     892     result_column, func, func_args, func_kwargs, input_column
#     893 )
#     895 # overwrite existing result-columns, generate intermediates only once
#     896 for spec in impls["chunk_funcs"]:
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/dataframe/groupby.py:950, in _build_agg_args_single(result_column, func, func_args, func_kwargs, input_column)
#     947     return _build_agg_args_custom(result_column, func, input_column)
#     949 else:
# --> 950     raise ValueError(f"unknown aggregate {func}")
#
# ValueError: unknown aggregate lambda

# %% [markdown]
# Now we time how long it takes to load the filtered data with each different partitioning scheme.
#
# ### pyarrow only
#
# We start using only pyarrow. While dask will likely improve the performance, we first want to see how pyarrow performs. Note the that pyarrow is the same engine used by dask, and that it supports multi-threaded column reads natively and by default.
#
# #### 100 MB in-memory partitions

# %%
# %%time
argo_ds = pq.ParquetDataset(
    pqt_100, 
    schema=PHY_schema,
    filters=filter_to_apply
)
argo_df = argo_ds.read(columns=cols).to_pandas()
# Out:
# CPU times: user 12.8 s, sys: 2.67 s, total: 15.5 s
# Wall time: 3.73 s

# %% [markdown]
# #### 300 MB in-memory partitions

# %%
# %%time
argo_ds = pq.ParquetDataset(
    pqt_300, 
    schema=PHY_schema,
    filters=filter_to_apply
)
argo_df = argo_ds.read(columns=cols).to_pandas()
# Out:
# CPU times: user 17.1 s, sys: 2.67 s, total: 19.8 s
# Wall time: 1.93 s

# %% [markdown]
# #### YYYY-MM on-disk partitions (filtering on JULD)

# %%
# %%time
argo_ds = pq.ParquetDataset(
    pqt_juld, 
    schema=PHY_schema,
    filters=filter_to_apply
)
argo_df = argo_ds.read(columns=cols).to_pandas()
# Out:
# CPU times: user 8min 2s, sys: 1min 18s, total: 9min 20s
# Wall time: 6min 45s

# %% [markdown]
# #### YYYY-MM on-disk partitions (filtering on partitioned parameter JULD_D)

# %%
# %%time
filter_to_apply_D = [("JULD_D",">=",time0),("JULD_D","<",time1),
                      ("LATITUDE",">=",lat0), ("LATITUDE","<=",lat1),
                      ("LONGITUDE",">=",lon0), ("LONGITUDE","<=",lon1),
                      ("PRES_ADJUSTED",">=",0),("PRES_ADJUSTED","<=",50),
                      (ref_var,">=",-1e30),(ref_var,"<=",+1e30)]
argo_ds = pq.ParquetDataset(
    pqt_juld, 
    schema=PHY_schema,
    filters=filter_to_apply_D
)
argo_df = argo_ds.read(columns=cols).to_pandas()
# Out:
# CPU times: user 48.3 s, sys: 25.2 s, total: 1min 13s
# Wall time: 2min 54s

# %% [markdown]
# ### pyarrow+dask
#
# We start using only pyarrow. While dask will likely improve the performance, we first want to see how pyarrow performs. Note the that pyarrow is the same engine used by dask, and that it supports multi-threaded column reads natively and by default.

# %%
import dask
import dask.dataframe as dd

# %% [markdown]
# #### 100 MB in-memory partitions

# %%
# %%time
ddf = dd.read_parquet(
    pqt_100,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True} ,
    schema=PHY_schema,
    columns = cols,
    filters = filter_to_apply
    )
ddf.persist()
# Out:
# CPU times: user 9.06 s, sys: 3.42 s, total: 12.5 s
# Wall time: 2.4 s
# Dask DataFrame Structure:
#                 TEMP_ADJUSTED LATITUDE LONGITUDE PRES_ADJUSTED
# npartitions=287
#                       float32  float64   float64       float32
#                           ...      ...       ...           ...
# ...                       ...      ...       ...           ...
#                           ...      ...       ...           ...
#                           ...      ...       ...           ...
# Dask Name: read_parquet, 1 expression
# Expr=FromGraph(bed8962)

# %% [markdown]
# #### 300 MB in-memory partitions

# %%
# %%time
ddf = dd.read_parquet(
    pqt_300,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True},
    columns = cols,
    filters = filter_to_apply
    )
ddf.persist()
# Out:
# CPU times: user 12.1 s, sys: 6.06 s, total: 18.1 s
# Wall time: 1.82 s
# Dask DataFrame Structure:
#                 TEMP_ADJUSTED LATITUDE LONGITUDE PRES_ADJUSTED
# npartitions=184
#                       float32  float64   float64       float32
#                           ...      ...       ...           ...
# ...                       ...      ...       ...           ...
#                           ...      ...       ...           ...
#                           ...      ...       ...           ...
# Dask Name: read_parquet, 1 expression
# Expr=FromGraph(bda53fc)

# %% [markdown]
# #### YYYY-MM on-disk partitions (JULD_D)

# %%
# %%time
ddf = dd.read_parquet(
    pqt_juld,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True},
    columns = cols,
    filters = filter_to_apply_D
    )
ddf.persist()
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File <timed exec>:8
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_collection.py:447, in FrameBase.persist(self, fuse, **kwargs)
#     445 def persist(self, fuse=True, **kwargs):
#     446     out = self.optimize(fuse=fuse)
# --> 447     return DaskMethodsMixin.persist(out, **kwargs)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:349, in DaskMethodsMixin.persist(self, **kwargs)
#     310 def persist(self, **kwargs):
#     311     """Persist this dask collection into memory
#     312
#     313     This turns a lazy Dask collection into a Dask collection with the same
#    (...)
#     347     dask.persist
#     348     """
# --> 349     (result,) = persist(self, traverse=False, **kwargs)
#     350     return result
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:990, in persist(traverse, optimize_graph, scheduler, *args, **kwargs)
#     985                 results = client.persist(
#     986                     collections, optimize_graph=optimize_graph, **kwargs
#     987                 )
#     988                 return repack(results)
# --> 990 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#     991 keys, postpersists = [], []
#     992 for a in collections:
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:427, in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     425 graphs = []
#     426 for opt, val in groups.items():
# --> 427     dsk, keys = _extract_graph_and_keys(val)
#     428     dsk = opt(dsk, keys, **kwargs)
#     430     for opt_inner in optimizations:
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:453, in _extract_graph_and_keys(vals)
#     451 graphs, keys = [], []
#     452 for v in vals:
# --> 453     graphs.append(v.__dask_graph__())
#     454     keys.append(v.__dask_keys__())
#     456 if any(isinstance(graph, HighLevelGraph) for graph in graphs):
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_collection.py:559, in FrameBase.__dask_graph__(self)
#     557 out = self.expr
#     558 out = out.lower_completely()
# --> 559 return out.__dask_graph__()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_core.py:509, in Expr.__dask_graph__(self)
#     506     continue
#     507 seen.add(expr._name)
# --> 509 layers.append(expr._layer())
#     510 for operand in expr.dependencies():
#     511     stack.append(operand)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_core.py:233, in Expr._layer(self)
#     210 def _layer(self) -> dict:
#     211     """The graph layer added by this expression
#     212
#     213     Examples
#    (...)
#     230     Expr.__dask_graph__
#     231     """
# --> 233     return {(self._name, i): self._task(i) for i in range(self.npartitions)}
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:2933, in PartitionsFiltered.npartitions(self)
#    2931 if self._filtered:
#    2932     return len(self._partitions)
# -> 2933 return super().npartitions
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:2918, in PartitionsFiltered.divisions(self)
#    2915 @functools.cached_property
#    2916 def divisions(self):
#    2917     # Common case: Use self._divisions()
# -> 2918     full_divisions = super().divisions
#    2919     if not self._filtered:
#    2920         return full_divisions
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/io/parquet.py:1289, in ReadParquetFSSpec._divisions(self)
#    1288 def _divisions(self):
# -> 1289     return self._plan["divisions"]
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/io/parquet.py:1422, in ReadParquetFSSpec._plan(self)
#    1420 dataset_token = tokenize(dataset_info)
#    1421 if dataset_token not in _cached_plan:
# -> 1422     parts, stats, common_kwargs = self.engine._construct_collection_plan(
#    1423         dataset_info
#    1424     )
#    1426     # Make sure parts and stats are aligned
#    1427     parts, stats = _align_statistics(parts, stats)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:1452, in ArrowDatasetEngine._construct_collection_plan(cls, dataset_info)
#    1446 else:
#    1447     # We DON'T have a global _metadata file to work with.
#    1448     # We should loop over files in parallel
#    1450     if filters and partitions:
#    1451         # Start with sorted (by path) list of file-based fragments
# -> 1452         all_files = sorted(
#    1453             (frag for frag in ds.get_fragments(ds_filters)),
#    1454             key=lambda x: natural_sort_key(x.path),
#    1455         )
#    1456     else:
#    1457         # Collect list of file paths.
#    1458         # If valid_paths is not None, the user passed in a list
#    1459         # of files containing a _metadata file.  Since we used
#    1460         # the _metadata file to generate our dataset object , we need
#    1461         # to ignore any file fragments that are not in the list.
#    1462         all_files = sorted(ds.files, key=natural_sort_key)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:1453, in <genexpr>(.0)
#    1446 else:
#    1447     # We DON'T have a global _metadata file to work with.
#    1448     # We should loop over files in parallel
#    1450     if filters and partitions:
#    1451         # Start with sorted (by path) list of file-based fragments
#    1452         all_files = sorted(
# -> 1453             (frag for frag in ds.get_fragments(ds_filters)),
#    1454             key=lambda x: natural_sort_key(x.path),
#    1455         )
#    1456     else:
#    1457         # Collect list of file paths.
#    1458         # If valid_paths is not None, the user passed in a list
#    1459         # of files containing a _metadata file.  Since we used
#    1460         # the _metadata file to generate our dataset object , we need
#    1461         # to ignore any file fragments that are not in the list.
#    1462         all_files = sorted(ds.files, key=natural_sort_key)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/_dataset.pyx:258, in _get_fragments()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/_compute.pyx:2700, in pyarrow._compute._bind()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/error.pxi:154, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Function 'greater_equal' has no kernel matching input types (string, timestamp[us])

# %% [markdown]
# ### pyarrow+dask cluster
#
# We start using only pyarrow. While dask will likely improve the performance, we first want to see how pyarrow performs. Note the that pyarrow is the same engine used by dask, and that it supports multi-threaded column reads natively and by default.

# %%
from dask.distributed import Client
client = Client(n_workers=10, threads_per_worker=10, processes=True, memory_limit='auto')
client
# Out:
# <Client: 'tcp://127.0.0.1:41829' processes=10 threads=100, memory=271.27 GiB>

# %% [markdown]
# #### 100 MB in-memory partitions

# %%
# %%time
ddf = dd.read_parquet(
    pqt_100,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True} ,
    schema=PHY_schema,
    columns = cols,
    filters = filter_to_apply
    )
ddf.persist()
# Out:
# CPU times: user 155 ms, sys: 30.9 ms, total: 186 ms
# Wall time: 171 ms
# Dask DataFrame Structure:
#                 TEMP_ADJUSTED LATITUDE LONGITUDE PRES_ADJUSTED
# npartitions=287
#                       float32  float64   float64       float32
#                           ...      ...       ...           ...
# ...                       ...      ...       ...           ...
#                           ...      ...       ...           ...
#                           ...      ...       ...           ...
# Dask Name: read_parquet, 1 expression
# Expr=FromGraph(cee307f)

# %% [markdown]
# #### 300 MB in-memory partitions

# %%
# %%time
ddf = dd.read_parquet(
    pqt_300,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True},
    columns = cols,
    filters = filter_to_apply
    )
ddf.persist()
# Out:
# CPU times: user 145 ms, sys: 28.5 ms, total: 174 ms
# Wall time: 166 ms
# Dask DataFrame Structure:
#                 TEMP_ADJUSTED LATITUDE LONGITUDE PRES_ADJUSTED
# npartitions=184
#                       float32  float64   float64       float32
#                           ...      ...       ...           ...
# ...                       ...      ...       ...           ...
#                           ...      ...       ...           ...
#                           ...      ...       ...           ...
# Dask Name: read_parquet, 1 expression
# Expr=FromGraph(bd0b748)

# %% [markdown]
# #### YYYY-MM on-disk partitions (on JULD)

# %%
# %%time
ddf = dd.read_parquet(
    pqt_juld,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True},
    columns = cols,
    filters = filter_to_apply
    )
ddf.persist()
# Out:
# CPU times: user 45 s, sys: 35.7 s, total: 1min 20s
# Wall time: 5min 15s
# Dask DataFrame Structure:
#                TEMP_ADJUSTED LATITUDE LONGITUDE PRES_ADJUSTED
# npartitions=54
#                      float32  float64   float64       float32
#                          ...      ...       ...           ...
# ...                      ...      ...       ...           ...
#                          ...      ...       ...           ...
#                          ...      ...       ...           ...
# Dask Name: read_parquet, 1 expression
# Expr=FromGraph(626034d)

# %% [markdown]
# #### YYYY-MM on-disk partitions (on JULD_D)

# %%
# %%time
ddf = dd.read_parquet(
    pqt_juld,
    engine="pyarrow",
    storage_options={"anon": True, "use_ssl": True},
    columns = cols,
    filters = filter_to_apply_D
    )
ddf.persist()
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File <timed exec>:8
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_collection.py:447, in FrameBase.persist(self, fuse, **kwargs)
#     445 def persist(self, fuse=True, **kwargs):
#     446     out = self.optimize(fuse=fuse)
# --> 447     return DaskMethodsMixin.persist(out, **kwargs)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:349, in DaskMethodsMixin.persist(self, **kwargs)
#     310 def persist(self, **kwargs):
#     311     """Persist this dask collection into memory
#     312
#     313     This turns a lazy Dask collection into a Dask collection with the same
#    (...)
#     347     dask.persist
#     348     """
# --> 349     (result,) = persist(self, traverse=False, **kwargs)
#     350     return result
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:985, in persist(traverse, optimize_graph, scheduler, *args, **kwargs)
#     983         else:
#     984             if client.get == schedule:
# --> 985                 results = client.persist(
#     986                     collections, optimize_graph=optimize_graph, **kwargs
#     987                 )
#     988                 return repack(results)
#     990 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/distributed/client.py:3780, in Client.persist(self, collections, optimize_graph, workers, allow_other_workers, resources, retries, priority, fifo_timeout, actors, **kwargs)
#    3776 assert all(map(dask.is_dask_collection, collections))
#    3777 metadata = SpanMetadata(
#    3778     collections=[get_collections_metadata(v) for v in collections]
#    3779 )
# -> 3780 dsk = self.collections_to_dsk(collections, optimize_graph, **kwargs)
#    3782 names = {k for c in collections for k in flatten(c.__dask_keys__())}
#    3784 futures = self._graph_to_futures(
#    3785     dsk,
#    3786     names,
#    (...)
#    3794     span_metadata=metadata,
#    3795 )
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/distributed/client.py:4915, in Client.collections_to_dsk(collections, *args, **kwargs)
#    4912 @staticmethod
#    4913 def collections_to_dsk(collections, *args, **kwargs):
#    4914     """Convert many collections into a single dask graph, after optimization"""
# -> 4915     return collections_to_dsk(collections, *args, **kwargs)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:427, in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     425 graphs = []
#     426 for opt, val in groups.items():
# --> 427     dsk, keys = _extract_graph_and_keys(val)
#     428     dsk = opt(dsk, keys, **kwargs)
#     430     for opt_inner in optimizations:
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/base.py:453, in _extract_graph_and_keys(vals)
#     451 graphs, keys = [], []
#     452 for v in vals:
# --> 453     graphs.append(v.__dask_graph__())
#     454     keys.append(v.__dask_keys__())
#     456 if any(isinstance(graph, HighLevelGraph) for graph in graphs):
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_collection.py:559, in FrameBase.__dask_graph__(self)
#     557 out = self.expr
#     558 out = out.lower_completely()
# --> 559 return out.__dask_graph__()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_core.py:509, in Expr.__dask_graph__(self)
#     506     continue
#     507 seen.add(expr._name)
# --> 509 layers.append(expr._layer())
#     510 for operand in expr.dependencies():
#     511     stack.append(operand)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_core.py:233, in Expr._layer(self)
#     210 def _layer(self) -> dict:
#     211     """The graph layer added by this expression
#     212
#     213     Examples
#    (...)
#     230     Expr.__dask_graph__
#     231     """
# --> 233     return {(self._name, i): self._task(i) for i in range(self.npartitions)}
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:2933, in PartitionsFiltered.npartitions(self)
#    2931 if self._filtered:
#    2932     return len(self._partitions)
# -> 2933 return super().npartitions
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:2918, in PartitionsFiltered.divisions(self)
#    2915 @functools.cached_property
#    2916 def divisions(self):
#    2917     # Common case: Use self._divisions()
# -> 2918     full_divisions = super().divisions
#    2919     if not self._filtered:
#    2920         return full_divisions
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/io/parquet.py:1289, in ReadParquetFSSpec._divisions(self)
#    1288 def _divisions(self):
# -> 1289     return self._plan["divisions"]
#
# File /vortexfs1/apps/python-3.9.10/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask_expr/io/parquet.py:1422, in ReadParquetFSSpec._plan(self)
#    1420 dataset_token = tokenize(dataset_info)
#    1421 if dataset_token not in _cached_plan:
# -> 1422     parts, stats, common_kwargs = self.engine._construct_collection_plan(
#    1423         dataset_info
#    1424     )
#    1426     # Make sure parts and stats are aligned
#    1427     parts, stats = _align_statistics(parts, stats)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:1452, in ArrowDatasetEngine._construct_collection_plan(cls, dataset_info)
#    1446 else:
#    1447     # We DON'T have a global _metadata file to work with.
#    1448     # We should loop over files in parallel
#    1450     if filters and partitions:
#    1451         # Start with sorted (by path) list of file-based fragments
# -> 1452         all_files = sorted(
#    1453             (frag for frag in ds.get_fragments(ds_filters)),
#    1454             key=lambda x: natural_sort_key(x.path),
#    1455         )
#    1456     else:
#    1457         # Collect list of file paths.
#    1458         # If valid_paths is not None, the user passed in a list
#    1459         # of files containing a _metadata file.  Since we used
#    1460         # the _metadata file to generate our dataset object , we need
#    1461         # to ignore any file fragments that are not in the list.
#    1462         all_files = sorted(ds.files, key=natural_sort_key)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:1453, in <genexpr>(.0)
#    1446 else:
#    1447     # We DON'T have a global _metadata file to work with.
#    1448     # We should loop over files in parallel
#    1450     if filters and partitions:
#    1451         # Start with sorted (by path) list of file-based fragments
#    1452         all_files = sorted(
# -> 1453             (frag for frag in ds.get_fragments(ds_filters)),
#    1454             key=lambda x: natural_sort_key(x.path),
#    1455         )
#    1456     else:
#    1457         # Collect list of file paths.
#    1458         # If valid_paths is not None, the user passed in a list
#    1459         # of files containing a _metadata file.  Since we used
#    1460         # the _metadata file to generate our dataset object , we need
#    1461         # to ignore any file fragments that are not in the list.
#    1462         all_files = sorted(ds.files, key=natural_sort_key)
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/_dataset.pyx:258, in _get_fragments()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/_compute.pyx:2700, in pyarrow._compute._bind()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/error.pxi:154, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/projects/ARGO/nc2parquet/venv/venv3.9/lib/python3.9/site-packages/pyarrow/error.pxi:91, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Function 'greater_equal' has no kernel matching input types (string, timestamp[us])

# %%
client.close()
